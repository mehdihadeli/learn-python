# %% [markdown]
# ## Choosing the Right Collection
#
# | Type    | Use When                                   | Mutable |
# | ------- | ------------------------------------------ | ------- |
# | `list`  | order matters and values may change        | yes     |
# | `tuple` | order matters and values should not change | no      |
# | `set`   | uniqueness matters                         | yes     |
# | `dict`  | you need key-value lookup                  | yes     |
#
# ---

# %% [markdown]
# ## Try It
#
# This section is mostly explanatory. Use the cell below for your own interactive experiments.

# %%
# Experiment here for: 12-choosing-the-right-collection
print("Add your own code in this cell.")
